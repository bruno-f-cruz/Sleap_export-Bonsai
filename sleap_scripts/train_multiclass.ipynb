# %%
import numpy as np
import tensorflow as tf
import sleap
from pathlib import Path
from sleap.nn.config import UNetConfig

# %%
dataset = r"C:\Users\neurogears\Desktop\SLEAPNetwork_v1\justTracks.pkg.slp" # load the dataset with tracks
skeleton_path = r"C:\Users\neurogears\Desktop\SLEAPNetwork_v1\skeleton.json"
videos = ["CameraTop_1904-01-07T00-00-00.avi"] # videos just in case, should not be needed as the dataset already has the path to the videos
run_name = "multiclass.topdown"
runs_folder = r"C:\Users\neurogears\Desktop\Sleap_demo\models"

# %%
skeleton = sleap.Skeleton.load_json(skeleton_path) # load the skeleton
labels = sleap.load_file(dataset) # load the label data
labels.tracks
# Out:
# [Track(spawned_on=0, name='1'), Track(spawned_on=0, name='2')]

# %%
skeleton = sleap.Skeleton.load_json(skeleton_path) # load the skeleton
labels = sleap.load_file(dataset) # load the label data

cfg = sleap.TrainingJobConfig.load_json(r"C:\Users\neurogears\Documents\git\SLEAP\sleap\sleap\training_profiles\baseline_large_rf.topdown.json") # start with a default settings
cfg.model.heads.centered_instance = None # Must disable the original head since only one head is allowed per full model

#cfg = sleap.TrainingJobConfig()
cfg.data.instance_cropping.center_on_part = "center"
cfg.data.instance_cropping.crop_size = 96

cfg.data.labels.skeletons = [skeleton] # load skeleton
cfg.data.labels.training_labels = dataset

cfg.model.backbone.unet = UNetConfig() # select the backbone
#configure the backbone
cfg.model.backbone.unet.max_stride = 32
cfg.model.backbone.unet.stem_stride = None
cfg.model.backbone.unet.filters = 24
cfg.model.backbone.unet.filters_rate = 1.5
cfg.model.backbone.unet.middle_block = True
cfg.model.backbone.unet.up_interpolate = True


#optimizer settings
cfg.optimization.preload_data = True
cfg.optimization.batches_per_epoch = None
cfg.optimization.min_batches_per_epoch = 200
cfg.optimization.val_batches_per_epoch = 100
cfg.optimization.min_val_batches_per_epoch = 10
cfg.optimization.batch_size = 4
cfg.optimization.epochs = 600

cfg.optimization.initial_learning_rate = 0.0001
cfg.optimization.learning_rate_schedule.reduce_on_plateau = True
cfg.optimization.learning_rate_schedule.reduction_factor = 0.1
cfg.optimization.learning_rate_schedule.plateau_min_delta = 1e-08
cfg.optimization.learning_rate_schedule.plateau_patience = 20
cfg.optimization.learning_rate_schedule.plateau_cooldown = 3
cfg.optimization.learning_rate_schedule.min_learning_rate = 1e-08


cfg.optimization.early_stopping.stop_training_on_plateau = True
cfg.optimization.early_stopping.plateau_min_delta = 1e-08
cfg.optimization.early_stopping.plateau_patience = 30

cfg.optimization.online_shuffling = True
cfg.optimization.shuffle_buffer_size = 128
cfg.optimization.prefetch = True


cfg.optimization.augmentation_config.scale = True
cfg.optimization.augmentation_config.scale_min = 0.9
cfg.optimization.augmentation_config.scale_max = 1.1


#Configure outputs
cfg.outputs.run_name = run_name
cfg.outputs.save_outputs = True
cfg.outputs.runs_folder = runs_folder
cfg.outputs.save_visualizations = True
cfg.outputs.checkpointing.initial_model = True
cfg.outputs.checkpointing.best_model = True

# %%
confmaps=sleap.nn.config.model.CenteredInstanceConfmapsHeadConfig(
    anchor_part=None,
    part_names = [part.name for part in skeleton.nodes],
    sigma = 2.5, output_stride = 4, loss_weight = 100, offset_refinement = False
    )#increase confmaps loss_weight

class_vectors=sleap.nn.config.ClassVectorsHeadConfig(
    classes = ['A', 'B'],
    output_stride=4,
    num_fc_layers=3,
    num_fc_units=256,
    global_pool=True,
    loss_weight = 0.5)

cfg.model.heads.multi_class_topdown = sleap.nn.config.MultiClassTopDownConfig(
    confmaps=confmaps,
    class_vectors=class_vectors,
)

# %%
trainer = sleap.nn.training.TopDownMultiClassModelTrainer.from_config(
    cfg, training_labels=labels
)
# Out:
# INFO:sleap.nn.training:Creating training and validation splits from validation fraction: 0.1
# INFO:sleap.nn.training:  Splits: Training = 79 / Validation = 9.

# %%
trainer.setup()
trainer.train()

print(trainer.keras_model.outputs[0].shape)
print(trainer.keras_model.outputs[1].shape)
# Out:
# INFO:sleap.nn.training:Setting up for training...
# INFO:sleap.nn.training:Setting up pipeline builders...
# INFO:sleap.nn.training:Setting up model...
# INFO:sleap.nn.training:Building test pipeline...
# INFO:sleap.nn.training:Loaded test example. [5.530s]
# INFO:sleap.nn.training:  Input shape: (96, 96, 1)
# INFO:sleap.nn.training:Created Keras model.
# INFO:sleap.nn.training:  Backbone: UNet(stacks=1, filters=24, filters_rate=1.5, kernel_size=3, stem_kernel_size=7, convs_per_block=2, stem_blocks=0, down_blocks=5, middle_block=True, up_blocks=3, up_interpolate=True, block_contraction=False)
# INFO:sleap.nn.training:  Max stride: 32
# INFO:sleap.nn.training:  Parameters: 1,791,145
# INFO:sleap.nn.training:  Heads:
# INFO:sleap.nn.training:    [0] = CenteredInstanceConfmapsHead(part_names=['Snout', 'TailBase', 'RightEar', 'LeftEar', 'center'], anchor_part=None, sigma=2.5, output_stride=4, loss_weight=100)
# INFO:sleap.nn.training:    [1] = ClassVectorsHead(classes=['A', 'B'], num_fc_layers=3, num_fc_units=256, global_pool=True, output_stride=4, loss_weight=0.5)
# INFO:sleap.nn.training:  Outputs:
# INFO:sleap.nn.training:    [0] = KerasTensor(type_spec=TensorSpec(shape=(None, 24, 24, 5), dtype=tf.float32, name=None), name='CenteredInstanceConfmapsHead/BiasAdd:0', description="created by layer 'CenteredInstanceConfmapsHead'")
# INFO:sleap.nn.training:    [1] = KerasTensor(type_spec=TensorSpec(shape=(None, 2), dtype=tf.float32, name=None), name='ClassVectorsHead/Softmax:0', description="created by layer 'ClassVectorsHead'")
# INFO:sleap.nn.training:Setting up data pipelines...
# INFO:sleap.nn.training:Training set: n = 79
# INFO:sleap.nn.training:Validation set: n = 9
# INFO:sleap.nn.training:Setting up optimization...
# INFO:sleap.nn.training:  Learning rate schedule: LearningRateScheduleConfig(reduce_on_plateau=True, reduction_factor=0.1, plateau_min_delta=1e-08, plateau_patience=20, plateau_cooldown=3, min_learning_rate=1e-08)
# INFO:sleap.nn.training:  Early stopping: EarlyStoppingConfig(stop_training_on_plateau=True, plateau_min_delta=1e-08, plateau_patience=30)
# INFO:sleap.nn.training:Setting up outputs...
# INFO:sleap.nn.training:Created run path: C:\Users\neurogears\Desktop\SLEAPNetwork_v1\models\multiclass.topdown_1
# INFO:sleap.nn.training:Setting up visualization...
# INFO:sleap.nn.training:Finished trainer set up. [10.3s]
# INFO:sleap.nn.training:Creating tf.data.Datasets for training data generation...
# INFO:sleap.nn.training:Finished creating training datasets. [8.0s]
# INFO:sleap.nn.training:Starting training loop...
# Epoch 1/600
# 200/200 - 22s - loss: 2.5328 - CenteredInstanceConfmapsHead_loss: 0.0219 - ClassVectorsHead_loss: 0.6927 - ClassVectorsHead_accuracy: 0.5138 - val_loss: 2.2057 - val_CenteredInstanceConfmapsHead_loss: 0.0186 - val_ClassVectorsHead_loss: 0.6898 - val_ClassVectorsHead_accuracy: 0.5000 - lr: 1.0000e-04 - 22s/epoch - 112ms/step
# Epoch 2/600
# 200/200 - 17s - loss: 2.0797 - CenteredInstanceConfmapsHead_loss: 0.0176 - ClassVectorsHead_loss: 0.6446 - ClassVectorsHead_accuracy: 0.6700 - val_loss: 1.8233 - val_CenteredInstanceConfmapsHead_loss: 0.0160 - val_ClassVectorsHead_loss: 0.4446 - val_ClassVectorsHead_accuracy: 0.8375 - lr: 1.0000e-04 - 17s/epoch - 86ms/step
# Epoch 3/600
# 200/200 - 17s - loss: 1.3790 - CenteredInstanceConfmapsHead_loss: 0.0127 - ClassVectorsHead_loss: 0.2107 - ClassVectorsHead_accuracy: 0.9200 - val_loss: 1.0704 - val_CenteredInstanceConfmapsHead_loss: 0.0103 - val_ClassVectorsHead_loss: 0.0842 - val_ClassVectorsHead_accuracy: 0.9725 - lr: 1.0000e-04 - 17s/epoch - 85ms/step
# Epoch 4/600
# 200/200 - 16s - loss: 0.7397 - CenteredInstanceConfmapsHead_loss: 0.0071 - ClassVectorsHead_loss: 0.0564 - ClassVectorsHead_accuracy: 0.9850 - val_loss: 0.7361 - val_CenteredInstanceConfmapsHead_loss: 0.0070 - val_ClassVectorsHead_loss: 0.0770 - val_ClassVectorsHead_accuracy: 0.9700 - lr: 1.0000e-04 - 16s/epoch - 78ms/step
# Epoch 5/600
# 200/200 - 15s - loss: 0.5771 - CenteredInstanceConfmapsHead_loss: 0.0055 - ClassVectorsHead_loss: 0.0601 - ClassVectorsHead_accuracy: 0.9787 - val_loss: 0.6849 - val_CenteredInstanceConfmapsHead_loss: 0.0065 - val_ClassVectorsHead_loss: 0.0769 - val_ClassVectorsHead_accuracy: 0.9775 - lr: 1.0000e-04 - 15s/epoch - 74ms/step
# Epoch 6/600
# 200/200 - 15s - loss: 0.4674 - CenteredInstanceConfmapsHead_loss: 0.0045 - ClassVectorsHead_loss: 0.0317 - ClassVectorsHead_accuracy: 0.9887 - val_loss: 0.7500 - val_CenteredInstanceConfmapsHead_loss: 0.0071 - val_ClassVectorsHead_loss: 0.0712 - val_ClassVectorsHead_accuracy: 0.9700 - lr: 1.0000e-04 - 15s/epoch - 77ms/step
# Epoch 7/600
# 200/200 - 16s - loss: 0.4193 - CenteredInstanceConfmapsHead_loss: 0.0041 - ClassVectorsHead_loss: 0.0157 - ClassVectorsHead_accuracy: 0.9950 - val_loss: 0.5185 - val_CenteredInstanceConfmapsHead_loss: 0.0051 - val_ClassVectorsHead_loss: 0.0174 - val_ClassVectorsHead_accuracy: 0.9950 - lr: 1.0000e-04 - 16s/epoch - 78ms/step
# Epoch 8/600
# 200/200 - 15s - loss: 0.3512 - CenteredInstanceConfmapsHead_loss: 0.0035 - ClassVectorsHead_loss: 0.0094 - ClassVectorsHead_accuracy: 0.9975 - val_loss: 0.5394 - val_CenteredInstanceConfmapsHead_loss: 0.0049 - val_ClassVectorsHead_loss: 0.0931 - val_ClassVectorsHead_accuracy: 0.9575 - lr: 1.0000e-04 - 15s/epoch - 74ms/step
# Epoch 9/600
# 200/200 - 15s - loss: 0.3280 - CenteredInstanceConfmapsHead_loss: 0.0032 - ClassVectorsHead_loss: 0.0190 - ClassVectorsHead_accuracy: 0.9912 - val_loss: 0.4969 - val_CenteredInstanceConfmapsHead_loss: 0.0048 - val_ClassVectorsHead_loss: 0.0240 - val_ClassVectorsHead_accuracy: 0.9925 - lr: 1.0000e-04 - 15s/epoch - 74ms/step
# Epoch 10/600
# 200/200 - 17s - loss: 0.2807 - CenteredInstanceConfmapsHead_loss: 0.0028 - ClassVectorsHead_loss: 0.0038 - ClassVectorsHead_accuracy: 1.0000 - val_loss: 0.4665 - val_CenteredInstanceConfmapsHead_loss: 0.0046 - val_ClassVectorsHead_loss: 0.0087 - val_ClassVectorsHead_accuracy: 1.0000 - lr: 1.0000e-04 - 17s/epoch - 83ms/step
# Epoch 11/600
# 200/200 - 18s - loss: 0.2662 - CenteredInstanceConfmapsHead_loss: 0.0027 - ClassVectorsHead_loss: 0.0018 - ClassVectorsHead_accuracy: 1.0000 - val_loss: 0.4539 - val_CenteredInstanceConfmapsHead_loss: 0.0044 - val_ClassVectorsHead_loss: 0.0302 - val_ClassVectorsHead_accuracy: 0.9850 - lr: 1.0000e-04 - 18s/epoch - 89ms/step
# Epoch 12/600
# 200/200 - 16s - loss: 0.2451 - CenteredInstanceConfmapsHead_loss: 0.0024 - ClassVectorsHead_loss: 0.0028 - ClassVectorsHead_accuracy: 1.0000 - val_loss: 0.4228 - val_CenteredInstanceConfmapsHead_loss: 0.0042 - val_ClassVectorsHead_loss: 0.0092 - val_ClassVectorsHead_accuracy: 1.0000 - lr: 1.0000e-04 - 16s/epoch - 79ms/step
# Epoch 13/600
# 200/200 - 14s - loss: 0.2400 - CenteredInstanceConfmapsHead_loss: 0.0024 - ClassVectorsHead_loss: 0.0094 - ClassVectorsHead_accuracy: 0.9975 - val_loss: 0.4249 - val_CenteredInstanceConfmapsHead_loss: 0.0040 - val_ClassVectorsHead_loss: 0.0473 - val_ClassVectorsHead_accuracy: 0.9775 - lr: 1.0000e-04 - 14s/epoch - 70ms/step
# Epoch 14/600
# 200/200 - 16s - loss: 0.2360 - CenteredInstanceConfmapsHead_loss: 0.0023 - ClassVectorsHead_loss: 0.0073 - ClassVectorsHead_accuracy: 0.9975 - val_loss: 0.4398 - val_CenteredInstanceConfmapsHead_loss: 0.0043 - val_ClassVectorsHead_loss: 0.0271 - val_ClassVectorsHead_accuracy: 0.9900 - lr: 1.0000e-04 - 16s/epoch - 81ms/step
# Epoch 15/600
# 200/200 - 14s - loss: 0.1881 - CenteredInstanceConfmapsHead_loss: 0.0019 - ClassVectorsHead_loss: 0.0020 - ClassVectorsHead_accuracy: 1.0000 - val_loss: 0.4150 - val_CenteredInstanceConfmapsHead_loss: 0.0040 - val_ClassVectorsHead_loss: 0.0205 - val_ClassVectorsHead_accuracy: 0.9875 - lr: 1.0000e-04 - 14s/epoch - 71ms/step
# Epoch 16/600
# 200/200 - 15s - loss: 0.1784 - CenteredInstanceConfmapsHead_loss: 0.0018 - ClassVectorsHead_loss: 6.7926e-04 - ClassVectorsHead_accuracy: 1.0000 - val_loss: 0.3752 - val_CenteredInstanceConfmapsHead_loss: 0.0037 - val_ClassVectorsHead_loss: 0.0156 - val_ClassVectorsHead_accuracy: 0.9950 - lr: 1.0000e-04 - 15s/epoch - 73ms/step
# Epoch 17/600
# 200/200 - 15s - loss: 0.1644 - CenteredInstanceConfmapsHead_loss: 0.0016 - ClassVectorsHead_loss: 7.5895e-04 - ClassVectorsHead_accuracy: 1.0000 - val_loss: 0.4389 - val_CenteredInstanceConfmapsHead_loss: 0.0040 - val_ClassVectorsHead_loss: 0.0867 - val_ClassVectorsHead_accuracy: 0.9650 - lr: 1.0000e-04 - 15s/epoch - 77ms/step
# Epoch 18/600
# 200/200 - 15s - loss: 0.1539 - CenteredInstanceConfmapsHead_loss: 0.0015 - ClassVectorsHead_loss: 4.2393e-04 - ClassVectorsHead_accuracy: 1.0000 - val_loss: 0.4052 - val_CenteredInstanceConfmapsHead_loss: 0.0039 - val_ClassVectorsHead_loss: 0.0248 - val_ClassVectorsHead_accuracy: 0.9900 - lr: 1.0000e-04 - 15s/epoch - 75ms/step
# Epoch 19/600
# 200/200 - 16s - loss: 0.1607 - CenteredInstanceConfmapsHead_loss: 0.0016 - ClassVectorsHead_loss: 0.0026 - ClassVectorsHead_accuracy: 1.0000 - val_loss: 0.4535 - val_CenteredInstanceConfmapsHead_loss: 0.0040 - val_ClassVectorsHead_loss: 0.1051 - val_ClassVectorsHead_accuracy: 0.9525 - lr: 1.0000e-04 - 16s/epoch - 82ms/step
# Epoch 20/600
# 200/200 - 14s - loss: 0.1305 - CenteredInstanceConfmapsHead_loss: 0.0013 - ClassVectorsHead_loss: 6.7238e-04 - ClassVectorsHead_accuracy: 1.0000 - val_loss: 0.4231 - val_CenteredInstanceConfmapsHead_loss: 0.0042 - val_ClassVectorsHead_loss: 0.0084 - val_ClassVectorsHead_accuracy: 0.9975 - lr: 1.0000e-04 - 14s/epoch - 72ms/step
# Epoch 21/600
# 200/200 - 15s - loss: 0.1234 - CenteredInstanceConfmapsHead_loss: 0.0012 - ClassVectorsHead_loss: 4.2246e-04 - ClassVectorsHead_accuracy: 1.0000 - val_loss: 0.4258 - val_CenteredInstanceConfmapsHead_loss: 0.0040 - val_ClassVectorsHead_loss: 0.0449 - val_ClassVectorsHead_accuracy: 0.9775 - lr: 1.0000e-04 - 15s/epoch - 74ms/step
# Epoch 22/600
# 200/200 - 16s - loss: 0.1213 - CenteredInstanceConfmapsHead_loss: 0.0012 - ClassVectorsHead_loss: 4.3767e-04 - ClassVectorsHead_accuracy: 1.0000 - val_loss: 0.4097 - val_CenteredInstanceConfmapsHead_loss: 0.0039 - val_ClassVectorsHead_loss: 0.0389 - val_ClassVectorsHead_accuracy: 0.9850 - lr: 1.0000e-04 - 16s/epoch - 80ms/step
# Epoch 23/600
# 200/200 - 15s - loss: 0.1127 - CenteredInstanceConfmapsHead_loss: 0.0011 - ClassVectorsHead_loss: 4.3899e-04 - ClassVectorsHead_accuracy: 1.0000 - val_loss: 0.4196 - val_CenteredInstanceConfmapsHead_loss: 0.0039 - val_ClassVectorsHead_loss: 0.0553 - val_ClassVectorsHead_accuracy: 0.9750 - lr: 1.0000e-04 - 15s/epoch - 76ms/step
# Epoch 24/600
# 200/200 - 20s - loss: 0.1216 - CenteredInstanceConfmapsHead_loss: 0.0012 - ClassVectorsHead_loss: 0.0035 - ClassVectorsHead_accuracy: 0.9987 - val_loss: 0.4468 - val_CenteredInstanceConfmapsHead_loss: 0.0041 - val_ClassVectorsHead_loss: 0.0735 - val_ClassVectorsHead_accuracy: 0.9650 - lr: 1.0000e-04 - 20s/epoch - 100ms/step
# Epoch 25/600
# 200/200 - 14s - loss: 0.0990 - CenteredInstanceConfmapsHead_loss: 9.8866e-04 - ClassVectorsHead_loss: 2.0877e-04 - ClassVectorsHead_accuracy: 1.0000 - val_loss: 0.3980 - val_CenteredInstanceConfmapsHead_loss: 0.0038 - val_ClassVectorsHead_loss: 0.0377 - val_ClassVectorsHead_accuracy: 0.9775 - lr: 1.0000e-04 - 14s/epoch - 72ms/step
# Epoch 26/600
# 200/200 - 14s - loss: 0.0937 - CenteredInstanceConfmapsHead_loss: 9.3601e-04 - ClassVectorsHead_loss: 2.2272e-04 - ClassVectorsHead_accuracy: 1.0000 - val_loss: 0.4327 - val_CenteredInstanceConfmapsHead_loss: 0.0042 - val_ClassVectorsHead_loss: 0.0328 - val_ClassVectorsHead_accuracy: 0.9800 - lr: 1.0000e-04 - 14s/epoch - 69ms/step
# Epoch 27/600
# 200/200 - 14s - loss: 0.0846 - CenteredInstanceConfmapsHead_loss: 8.4495e-04 - ClassVectorsHead_loss: 2.5724e-04 - ClassVectorsHead_accuracy: 1.0000 - val_loss: 0.4135 - val_CenteredInstanceConfmapsHead_loss: 0.0040 - val_ClassVectorsHead_loss: 0.0233 - val_ClassVectorsHead_accuracy: 0.9825 - lr: 1.0000e-04 - 14s/epoch - 69ms/step
# Epoch 28/600
# 200/200 - 14s - loss: 0.0835 - CenteredInstanceConfmapsHead_loss: 8.3376e-04 - ClassVectorsHead_loss: 2.9702e-04 - ClassVectorsHead_accuracy: 1.0000 - val_loss: 0.4227 - val_CenteredInstanceConfmapsHead_loss: 0.0042 - val_ClassVectorsHead_loss: 0.0125 - val_ClassVectorsHead_accuracy: 0.9925 - lr: 1.0000e-04 - 14s/epoch - 69ms/step
# Epoch 29/600
# 200/200 - 15s - loss: 0.0843 - CenteredInstanceConfmapsHead_loss: 8.4182e-04 - ClassVectorsHead_loss: 2.1969e-04 - ClassVectorsHead_accuracy: 1.0000 - val_loss: 0.4141 - val_CenteredInstanceConfmapsHead_loss: 0.0041 - val_ClassVectorsHead_loss: 0.0114 - val_ClassVectorsHead_accuracy: 0.9925 - lr: 1.0000e-04 - 15s/epoch - 75ms/step
# Epoch 30/600
# 200/200 - 13s - loss: 0.0748 - CenteredInstanceConfmapsHead_loss: 7.4683e-04 - ClassVectorsHead_loss: 2.2607e-04 - ClassVectorsHead_accuracy: 1.0000 - val_loss: 0.4572 - val_CenteredInstanceConfmapsHead_loss: 0.0041 - val_ClassVectorsHead_loss: 0.0990 - val_ClassVectorsHead_accuracy: 0.9575 - lr: 1.0000e-04 - 13s/epoch - 67ms/step
# Epoch 31/600
# 200/200 - 13s - loss: 0.0719 - CenteredInstanceConfmapsHead_loss: 7.1767e-04 - ClassVectorsHead_loss: 1.7931e-04 - ClassVectorsHead_accuracy: 1.0000 - val_loss: 0.3821 - val_CenteredInstanceConfmapsHead_loss: 0.0037 - val_ClassVectorsHead_loss: 0.0220 - val_ClassVectorsHead_accuracy: 0.9875 - lr: 1.0000e-04 - 13s/epoch - 65ms/step
# Epoch 32/600
# 200/200 - 14s - loss: 0.0651 - CenteredInstanceConfmapsHead_loss: 6.5014e-04 - ClassVectorsHead_loss: 2.1628e-04 - ClassVectorsHead_accuracy: 1.0000 - val_loss: 0.4460 - val_CenteredInstanceConfmapsHead_loss: 0.0040 - val_ClassVectorsHead_loss: 0.0941 - val_ClassVectorsHead_accuracy: 0.9675 - lr: 1.0000e-04 - 14s/epoch - 69ms/step
# Epoch 33/600
# 200/200 - 15s - loss: 0.0665 - CenteredInstanceConfmapsHead_loss: 6.6412e-04 - ClassVectorsHead_loss: 1.2919e-04 - ClassVectorsHead_accuracy: 1.0000 - val_loss: 0.4098 - val_CenteredInstanceConfmapsHead_loss: 0.0039 - val_ClassVectorsHead_loss: 0.0434 - val_ClassVectorsHead_accuracy: 0.9750 - lr: 1.0000e-04 - 15s/epoch - 74ms/step
# Epoch 34/600
# 200/200 - 14s - loss: 0.0573 - CenteredInstanceConfmapsHead_loss: 5.7194e-04 - ClassVectorsHead_loss: 1.9553e-04 - ClassVectorsHead_accuracy: 1.0000 - val_loss: 0.4227 - val_CenteredInstanceConfmapsHead_loss: 0.0041 - val_ClassVectorsHead_loss: 0.0313 - val_ClassVectorsHead_accuracy: 0.9825 - lr: 1.0000e-04 - 14s/epoch - 70ms/step
# Epoch 35/600
# 200/200 - 14s - loss: 0.0628 - CenteredInstanceConfmapsHead_loss: 6.2681e-04 - ClassVectorsHead_loss: 2.1700e-04 - ClassVectorsHead_accuracy: 1.0000 - val_loss: 0.4071 - val_CenteredInstanceConfmapsHead_loss: 0.0040 - val_ClassVectorsHead_loss: 0.0158 - val_ClassVectorsHead_accuracy: 0.9925 - lr: 1.0000e-04 - 14s/epoch - 69ms/step
# Epoch 36/600
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 200/200 - 14s - loss: 0.0527 - CenteredInstanceConfmapsHead_loss: 5.2604e-04 - ClassVectorsHead_loss: 1.6630e-04 - ClassVectorsHead_accuracy: 1.0000 - val_loss: 0.4348 - val_CenteredInstanceConfmapsHead_loss: 0.0042 - val_ClassVectorsHead_loss: 0.0365 - val_ClassVectorsHead_accuracy: 0.9800 - lr: 1.0000e-04 - 14s/epoch - 69ms/step
# Epoch 37/600
# 200/200 - 15s - loss: 0.0421 - CenteredInstanceConfmapsHead_loss: 4.2018e-04 - ClassVectorsHead_loss: 1.1938e-04 - ClassVectorsHead_accuracy: 1.0000 - val_loss: 0.4055 - val_CenteredInstanceConfmapsHead_loss: 0.0038 - val_ClassVectorsHead_loss: 0.0417 - val_ClassVectorsHead_accuracy: 0.9775 - lr: 1.0000e-05 - 15s/epoch - 75ms/step
# Epoch 38/600
# 200/200 - 14s - loss: 0.0388 - CenteredInstanceConfmapsHead_loss: 3.8771e-04 - ClassVectorsHead_loss: 1.3067e-04 - ClassVectorsHead_accuracy: 1.0000 - val_loss: 0.4201 - val_CenteredInstanceConfmapsHead_loss: 0.0039 - val_ClassVectorsHead_loss: 0.0596 - val_ClassVectorsHead_accuracy: 0.9675 - lr: 1.0000e-05 - 14s/epoch - 71ms/step
# Epoch 39/600
# 200/200 - 17s - loss: 0.0386 - CenteredInstanceConfmapsHead_loss: 3.8499e-04 - ClassVectorsHead_loss: 1.1460e-04 - ClassVectorsHead_accuracy: 1.0000 - val_loss: 0.4105 - val_CenteredInstanceConfmapsHead_loss: 0.0040 - val_ClassVectorsHead_loss: 0.0191 - val_ClassVectorsHead_accuracy: 0.9925 - lr: 1.0000e-05 - 17s/epoch - 84ms/step
# Epoch 40/600
# 200/200 - 19s - loss: 0.0385 - CenteredInstanceConfmapsHead_loss: 3.8463e-04 - ClassVectorsHead_loss: 1.2219e-04 - ClassVectorsHead_accuracy: 1.0000 - val_loss: 0.4153 - val_CenteredInstanceConfmapsHead_loss: 0.0040 - val_ClassVectorsHead_loss: 0.0368 - val_ClassVectorsHead_accuracy: 0.9800 - lr: 1.0000e-05 - 19s/epoch - 93ms/step
# Epoch 41/600
# 200/200 - 13s - loss: 0.0379 - CenteredInstanceConfmapsHead_loss: 3.7878e-04 - ClassVectorsHead_loss: 1.2955e-04 - ClassVectorsHead_accuracy: 1.0000 - val_loss: 0.4216 - val_CenteredInstanceConfmapsHead_loss: 0.0039 - val_ClassVectorsHead_loss: 0.0565 - val_ClassVectorsHead_accuracy: 0.9675 - lr: 1.0000e-05 - 13s/epoch - 64ms/step
# Epoch 42/600
# 200/200 - 13s - loss: 0.0378 - CenteredInstanceConfmapsHead_loss: 3.7733e-04 - ClassVectorsHead_loss: 1.3474e-04 - ClassVectorsHead_accuracy: 1.0000 - val_loss: 0.4058 - val_CenteredInstanceConfmapsHead_loss: 0.0039 - val_ClassVectorsHead_loss: 0.0348 - val_ClassVectorsHead_accuracy: 0.9800 - lr: 1.0000e-05 - 13s/epoch - 65ms/step
# Epoch 43/600
# 200/200 - 14s - loss: 0.0377 - CenteredInstanceConfmapsHead_loss: 3.7614e-04 - ClassVectorsHead_loss: 1.0770e-04 - ClassVectorsHead_accuracy: 1.0000 - val_loss: 0.4187 - val_CenteredInstanceConfmapsHead_loss: 0.0040 - val_ClassVectorsHead_loss: 0.0291 - val_ClassVectorsHead_accuracy: 0.9875 - lr: 1.0000e-05 - 14s/epoch - 71ms/step
# Epoch 44/600
# 200/200 - 15s - loss: 0.0369 - CenteredInstanceConfmapsHead_loss: 3.6857e-04 - ClassVectorsHead_loss: 1.1007e-04 - ClassVectorsHead_accuracy: 1.0000 - val_loss: 0.4040 - val_CenteredInstanceConfmapsHead_loss: 0.0039 - val_ClassVectorsHead_loss: 0.0301 - val_ClassVectorsHead_accuracy: 0.9900 - lr: 1.0000e-05 - 15s/epoch - 76ms/step
# Epoch 45/600
# 200/200 - 15s - loss: 0.0363 - CenteredInstanceConfmapsHead_loss: 3.6245e-04 - ClassVectorsHead_loss: 1.3999e-04 - ClassVectorsHead_accuracy: 1.0000 - val_loss: 0.4140 - val_CenteredInstanceConfmapsHead_loss: 0.0039 - val_ClassVectorsHead_loss: 0.0397 - val_ClassVectorsHead_accuracy: 0.9775 - lr: 1.0000e-05 - 15s/epoch - 74ms/step
# Epoch 46/600
# 200/200 - 14s - loss: 0.0358 - CenteredInstanceConfmapsHead_loss: 3.5744e-04 - ClassVectorsHead_loss: 1.2674e-04 - ClassVectorsHead_accuracy: 1.0000 - val_loss: 0.4293 - val_CenteredInstanceConfmapsHead_loss: 0.0040 - val_ClassVectorsHead_loss: 0.0549 - val_ClassVectorsHead_accuracy: 0.9725 - lr: 1.0000e-05 - 14s/epoch - 72ms/step
# Epoch 46: early stopping
# INFO:sleap.nn.training:Finished training loop. [11.7 min]
# INFO:sleap.nn.training:Deleting visualization directory: C:\Users\neurogears\Desktop\SLEAPNetwork_v1\models\multiclass.topdown_1\viz
# INFO:sleap.nn.training:Saving evaluation metrics to model folder...
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# INFO:sleap.nn.evals:Saved predictions: C:\Users\neurogears\Desktop\SLEAPNetwork_v1\models\multiclass.topdown_1\labels_pr.train.slp
# INFO:sleap.nn.evals:Saved metrics: C:\Users\neurogears\Desktop\SLEAPNetwork_v1\models\multiclass.topdown_1\metrics.train.npz
# INFO:sleap.nn.evals:OKS mAP: 0.446055
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# INFO:sleap.nn.evals:Saved predictions: C:\Users\neurogears\Desktop\SLEAPNetwork_v1\models\multiclass.topdown_1\labels_pr.val.slp
# INFO:sleap.nn.evals:Saved metrics: C:\Users\neurogears\Desktop\SLEAPNetwork_v1\models\multiclass.topdown_1\metrics.val.npz
# INFO:sleap.nn.evals:OKS mAP: 0.017238
# (None, 24, 24, 5)
# (None, 2)

# %%
from test_run import *
import test_utils
from pathlib import Path
from sleap.nn.peak_finding import find_local_peaks, find_global_peaks, make_centered_bboxes, crop_bboxes
from sleap.nn.data.utils import  describe_tensors

id_model = tf.keras.models.load_model(runs_folder + "\\" + run_name + "\\best_model.h5", compile = False)

#Define the full mode
class TopDownInferenceModel(tf.keras.Model):
    def __init__(
        self,
        this_model,
        td_output_stride,
        **kwargs
    ):
        super().__init__(**kwargs)
        self.this_model = this_model
        self.td_output_stride = td_output_stride


    @tf.function
    def stage2(self, im):
        """Stage 2: Predict pose in each crop"""
        # Preprocessing
        X = tf.cast(im, tf.float32) / 255
        X = tf.image.resize(X, [96, 96])

        # Forward pass
        cms, class_probs = self.this_model(X)

        # Find keypoints in each crop
        #     pts: (n_centroids, n_nodes, 2)
        #     vals: (n_centroids, n_nodes)
        pts, vals = find_global_peaks(cms, threshold=0.2, refinement="integral")

        # Adjust coordinates for output stride
        pts = pts * self.td_output_stride

        return {"instance_peaks": pts, "instance_peak_vals": vals, "class_probabilities": class_probs}

    def call(self, imgs):
        preds = self.stage2(imgs)
        return preds

td_output_stride = 4
td_input_size = [96, 96] #Hardcoded in the network

inference_model = TopDownInferenceModel(id_model,td_output_stride)

preds = inference_model.predict(np.zeros((4, 96, 96, 1), dtype="uint8"))
describe_tensors(preds)

inference_model.save(
    r"C:\Users\neurogears\Desktop\SLEAPNetwork_v1\Bonsai\customNetwork" + "\\" + run_name,
    save_format="tf", save_traces=True)
# Out:
#      instance_peaks: type=ndarray, shape=(4, 5, 2), dtype=float32, device=N/A
#  instance_peak_vals: type=ndarray, shape=(4, 5), dtype=float32, device=N/A
# class_probabilities: type=ndarray, shape=(4, 2), dtype=float32, device=N/A
# INFO:tensorflow:Assets written to: C:\Users\neurogears\Desktop\SLEAPNetwork_v1\Bonsai\customNetwork\multiclass.topdown.2\assets

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2

#Import the network
imported = tf.saved_model.load(r"C:\Users\neurogears\Desktop\SLEAPNetwork_v1\Bonsai\customNetwork" + "\\" + run_name)

model = imported.signatures["serving_default"]
print(model)

full_model = tf.function(lambda x: model(x))

full_model = full_model.get_concrete_function(
    tf.TensorSpec(model.inputs[0].shape, model.inputs[0].dtype))
frozen_func = convert_variables_to_constants_v2(full_model)
frozen_func.graph.as_graph_def()

print("Frozen model inputs: ")
print(frozen_func.inputs)
print("Frozen model outputs: ")
print(frozen_func.outputs)


tf.io.write_graph(graph_or_graph_def=frozen_func.graph,
               logdir=r"C:\Users\neurogears\Desktop\SLEAPNetwork_v1\Bonsai\customNetwork" + "\\" + run_name,
               name="frozen_graph.pb",
               as_text=False)
# Out:
# ConcreteFunction signature_wrapper(*, input_1)
#   Args:
#     input_1: uint8 Tensor, shape=(None, 96, 96, 1)
#   Returns:
#     {'class_probabilities': <1>, 'instance_peak_vals': <2>, 'instance_peaks': <3>}
#       <1>: float32 Tensor, shape=(None, 2)
#       <2>: float32 Tensor, shape=(None, 5)
#       <3>: float32 Tensor, shape=(None, 5, 2)
# Frozen model inputs:
# [<tf.Tensor 'x:0' shape=(None, 96, 96, 1) dtype=uint8>]
# Frozen model outputs:
# [<tf.Tensor 'Identity:0' shape=(None, 2) dtype=float32>, <tf.Tensor 'Identity_1:0' shape=(None, 5) dtype=float32>, <tf.Tensor 'Identity_2:0' shape=(None, 5, 2) dtype=float32>]
# 'C:\\Users\\neurogears\\Desktop\\SLEAPNetwork_v1\\Bonsai\\customNetwork\\multiclass.topdown\\frozen_graph.pb'
